# %%
import numpy as np 
import pandas as pd 
import os

dataset_path = '../dataset'

classes = [c for c in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, c))]

print("Classes found:", classes)
print("Total classes:", len(classes))

for cls in classes:
    count = len(os.listdir(os.path.join(dataset_path, cls)))
    print(f"{cls}: {count} images")
# Out:
# Classes found: ['AB+', 'AB-', 'A+', 'B-', 'B+', 'A-', 'O-', 'O+']
# Total classes: 8
# AB+: 708 images
# AB-: 761 images
# A+: 565 images
# B-: 741 images
# B+: 652 images
# A-: 1009 images
# O-: 712 images
# O+: 852 images

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from collections import Counter
import numpy as np
import os
import shutil
from sklearn.utils import resample
from tensorflow.keras.preprocessing.image import load_img, img_to_array, save_img
from tensorflow.keras.utils import image_dataset_from_directory
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# VGG16 ke liye (Transfer Learning)
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

print("TensorFlow version:", tf.__version__)
print("All libraries imported successfully! ✅")
# Out:
# TensorFlow version: 2.21.0
# All libraries imported successfully! ✅

# %%
dataset_path = "../dataset"

# %%
BATCH_SIZE = 32

# %%
from tensorflow.keras.utils import image_dataset_from_directory

dataset = image_dataset_from_directory(
    dataset_path,
    labels="inferred",
    label_mode="int",
    image_size=(64, 64),  # Resize images to standard size
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Found 6000 files belonging to 8 classes.

# %%
# Step 2: Check class distribution
class_names = dataset.class_names
class_counts = Counter()
for _, labels in dataset.unbatch():
    class_counts[int(labels.numpy())] += 1

print("Class Distribution:")
for i, count in class_counts.items():
    print(f"{class_names[i]}: {count}")
# Out:
# Class Distribution:
# O-: 712
# A-: 1009
# B-: 741
# B+: 652
# A+: 565
# O+: 852
# AB-: 761
# AB+: 708

# %%
import matplotlib.pyplot as plt

def plot_class_distribution(class_names, class_counts):
    classes = [class_names[i] for i in class_counts.keys()]
    counts = [class_counts[i] for i in class_counts.keys()]
    
    plt.figure(figsize=(10, 6))
    plt.bar(classes, counts, color='skyblue')
    plt.title("Dataset Class Distribution")
    plt.xlabel("Blood Group")
    plt.ylabel("Number of Images")
    for i, count in enumerate(counts):
        plt.text(i, count + 10, str(count), ha='center')
    plt.show()

# %%
plot_class_distribution(class_names, class_counts)

# %%
max_count = max(class_counts.values())

# %%
# Function to oversample a class
def oversample_class(class_id, count, max_count):
    # Ensure the dataset is unbatched for filtering
    unbatched_dataset = dataset.unbatch()
    
    # Filter the dataset for the specific class
    class_dataset = unbatched_dataset.filter(lambda img, lbl: tf.equal(lbl, class_id))
    
    # Calculate the number of repetitions needed
    repeat_factor = max_count // count + (max_count % count > 0)
    
    # Repeat the dataset to match the desired count
    return class_dataset.repeat(repeat_factor).take(max_count)

# %%
# Step 1: Balance the dataset
balanced_datasets = []
for class_id, count in class_counts.items():
    balanced_datasets.append(oversample_class(class_id, count, max_count))

# Step 2: Combine balanced datasets
balanced_dataset = tf.data.Dataset.sample_from_datasets(balanced_datasets)

# Step 3: Check balanced class distribution
balanced_class_counts = Counter([int(lbl.numpy()) for _, lbl in balanced_dataset])
plot_class_distribution(class_names, balanced_class_counts)

# Step 4: Batch the balanced dataset
balanced_dataset = balanced_dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
for sample in balanced_dataset.take(10) : 
    print(sample[0].shape)
# Out:
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)
# (32, 64, 64, 3)

# %%
balanced_dataset_unbatched = balanced_dataset.unbatch()
dataset_size = sum(1 for _ in balanced_dataset_unbatched)
print(f"Total dataset size: {dataset_size}")
# Out:
# Total dataset size: 8064

# %%
# Define split ratios
train_ratio = 0.7
val_ratio = 0.2

# Unbatch the dataset to work at the sample level
balanced_dataset_unbatched = balanced_dataset.unbatch()

# Compute sizes based on dataset size and desired splits
train_size = int(train_ratio * dataset_size)
val_size = int(val_ratio * dataset_size)

# Split the dataset into training, validation, and test
train_dataset = balanced_dataset_unbatched.take(train_size)
val_test_dataset = balanced_dataset_unbatched.skip(train_size)
val_dataset = val_test_dataset.take(val_size)
test_dataset = val_test_dataset.skip(val_size)

# Rebatch the datasets after splitting
train_dataset = train_dataset.batch(BATCH_SIZE, drop_remainder=True)
val_dataset = val_dataset.batch(BATCH_SIZE, drop_remainder=True)
test_dataset = test_dataset.batch(BATCH_SIZE, drop_remainder=True)

# Check the number of batches in each dataset
train_batch_count = sum(1 for _ in train_dataset)
val_batch_count = sum(1 for _ in val_dataset)
test_batch_count = sum(1 for _ in test_dataset)

print(f"Training dataset size: {train_batch_count * BATCH_SIZE}")
print(f"Validation dataset size: {val_batch_count * BATCH_SIZE}")
print(f"Testing dataset size: {test_batch_count * BATCH_SIZE}")
# Out:
# Training dataset size: 5632
# Validation dataset size: 1600
# Testing dataset size: 800

# %%
def create_high_accuracy_model():
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.3),

        tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.4),

        tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.4),

        tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.4),

        tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Dropout(0.5),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1024, activation='relu'),
        tf.keras.layers.Dropout(0.5),

        tf.keras.layers.Dense(len(class_names), activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model


# create the model
high_acc_model = create_high_accuracy_model()

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Define ReduceLROnPlateau callback to reduce learning rate when validation loss plateaus
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',       # Monitor validation loss
    factor=0.5,               # Reduce the learning rate by a factor of 0.5
    patience=3,               # Wait for 3 epochs without improvement before reducing LR
    verbose=1,                # Print a message when the learning rate is reduced
    min_lr=1e-6               # Minimum learning rate to avoid too small values
)

# Define EarlyStopping callback to stop training when validation loss doesn't improve
early_stop = EarlyStopping(
    monitor='val_loss',       # Monitor validation loss
    patience=5,               # Stop after 5 epochs without improvement
    verbose=1,                # Print a message when training is stopped
    restore_best_weights=True # Restore the model weights from the best epoch
)

# %%
# Train the model
history_high_acc = high_acc_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,  # Adjust the number of epochs based on your preference
    callbacks=[reduce_lr, early_stop]
)
# Out:
# Epoch 1/50
#     176/Unknown 20s 102ms/step - accuracy: 0.1370 - loss: 24.5800
# /opt/miniconda3/envs/bloodgroup/lib/python3.11/site-packages/keras/src/trainers/epoch_iterator.py:164: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 23s 121ms/step - accuracy: 0.1338 - loss: 7.2586 - val_accuracy: 0.1183 - val_loss: 2.0393 - learning_rate: 0.0010
# Epoch 2/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 22s 124ms/step - accuracy: 0.1762 - loss: 2.0257 - val_accuracy: 0.1183 - val_loss: 2.0346 - learning_rate: 0.0010
# Epoch 3/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 24s 135ms/step - accuracy: 0.3007 - loss: 1.7954 - val_accuracy: 0.1452 - val_loss: 1.9767 - learning_rate: 0.0010
# Epoch 4/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 23s 130ms/step - accuracy: 0.3699 - loss: 1.5994 - val_accuracy: 0.1183 - val_loss: 2.4024 - learning_rate: 0.0010
# Epoch 5/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 23s 132ms/step - accuracy: 0.4643 - loss: 1.4003 - val_accuracy: 0.1219 - val_loss: 2.5049 - learning_rate: 0.0010
# Epoch 6/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 23s 133ms/step - accuracy: 0.5551 - loss: 1.1752 - val_accuracy: 0.2966 - val_loss: 1.7725 - learning_rate: 0.0010
# Epoch 7/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 24s 135ms/step - accuracy: 0.6001 - loss: 1.0626 - val_accuracy: 0.4314 - val_loss: 1.3683 - learning_rate: 0.0010
# Epoch 8/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 24s 136ms/step - accuracy: 0.6430 - loss: 0.9503 - val_accuracy: 0.6238 - val_loss: 1.1389 - learning_rate: 0.0010
# Epoch 9/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 160s 911ms/step - accuracy: 0.6762 - loss: 0.8685 - val_accuracy: 0.5974 - val_loss: 1.0978 - learning_rate: 0.0010
# Epoch 10/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 20s 115ms/step - accuracy: 0.6977 - loss: 0.8025 - val_accuracy: 0.7010 - val_loss: 0.9273 - learning_rate: 0.0010
# Epoch 11/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 23s 130ms/step - accuracy: 0.7297 - loss: 0.7297 - val_accuracy: 0.7941 - val_loss: 0.7547 - learning_rate: 0.0010
# Epoch 12/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - accuracy: 0.7362 - loss: 0.6973 - val_accuracy: 0.7702 - val_loss: 0.7737 - learning_rate: 0.0010
# Epoch 13/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 22s 125ms/step - accuracy: 0.7389 - loss: 0.7022 - val_accuracy: 0.8076 - val_loss: 0.6594 - learning_rate: 0.0010
# Epoch 14/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 23s 131ms/step - accuracy: 0.7472 - loss: 0.6703 - val_accuracy: 0.7855 - val_loss: 0.7017 - learning_rate: 0.0010
# Epoch 15/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 24s 138ms/step - accuracy: 0.7632 - loss: 0.6265 - val_accuracy: 0.8211 - val_loss: 0.7335 - learning_rate: 0.0010
# Epoch 16/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - accuracy: 0.7643 - loss: 0.6292 - val_accuracy: 0.7862 - val_loss: 0.6490 - learning_rate: 0.0010
# Epoch 17/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 147ms/step - accuracy: 0.7604 - loss: 0.6094 - val_accuracy: 0.7843 - val_loss: 0.6923 - learning_rate: 0.0010
# Epoch 18/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - accuracy: 0.7745 - loss: 0.6035 - val_accuracy: 0.8223 - val_loss: 0.5406 - learning_rate: 0.0010
# Epoch 19/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 147ms/step - accuracy: 0.7639 - loss: 0.5981 - val_accuracy: 0.8211 - val_loss: 0.5336 - learning_rate: 0.0010
# Epoch 20/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - accuracy: 0.7760 - loss: 0.5741 - val_accuracy: 0.8487 - val_loss: 0.4824 - learning_rate: 0.0010
# Epoch 21/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - accuracy: 0.7899 - loss: 0.5537 - val_accuracy: 0.8272 - val_loss: 0.5683 - learning_rate: 0.0010
# Epoch 22/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 146ms/step - accuracy: 0.7816 - loss: 0.5763 - val_accuracy: 0.8039 - val_loss: 0.5942 - learning_rate: 0.0010
# Epoch 23/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.7912 - loss: 0.5525
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - accuracy: 0.7899 - loss: 0.5420 - val_accuracy: 0.8352 - val_loss: 0.5764 - learning_rate: 0.0010
# Epoch 24/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 153ms/step - accuracy: 0.8180 - loss: 0.4739 - val_accuracy: 0.8750 - val_loss: 0.4509 - learning_rate: 5.0000e-04
# Epoch 25/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 29s 162ms/step - accuracy: 0.8233 - loss: 0.4422 - val_accuracy: 0.8615 - val_loss: 0.4334 - learning_rate: 5.0000e-04
# Epoch 26/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 154ms/step - accuracy: 0.8215 - loss: 0.4474 - val_accuracy: 0.8713 - val_loss: 0.4248 - learning_rate: 5.0000e-04
# Epoch 27/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 24s 137ms/step - accuracy: 0.8272 - loss: 0.4416 - val_accuracy: 0.8615 - val_loss: 0.4541 - learning_rate: 5.0000e-04
# Epoch 28/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - accuracy: 0.8263 - loss: 0.4329 - val_accuracy: 0.8603 - val_loss: 0.4410 - learning_rate: 5.0000e-04
# Epoch 29/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 157ms/step - accuracy: 0.8217 - loss: 0.4463 - val_accuracy: 0.8830 - val_loss: 0.3838 - learning_rate: 5.0000e-04
# Epoch 30/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 35s 201ms/step - accuracy: 0.8298 - loss: 0.4249 - val_accuracy: 0.8517 - val_loss: 0.4440 - learning_rate: 5.0000e-04
# Epoch 31/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 159ms/step - accuracy: 0.8282 - loss: 0.4143 - val_accuracy: 0.8725 - val_loss: 0.4104 - learning_rate: 5.0000e-04
# Epoch 32/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8500 - loss: 0.3919
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - accuracy: 0.8393 - loss: 0.4096 - val_accuracy: 0.8609 - val_loss: 0.3888 - learning_rate: 5.0000e-04
# Epoch 33/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 147ms/step - accuracy: 0.8503 - loss: 0.3775 - val_accuracy: 0.8676 - val_loss: 0.3722 - learning_rate: 2.5000e-04
# Epoch 34/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 148ms/step - accuracy: 0.8508 - loss: 0.3637 - val_accuracy: 0.8848 - val_loss: 0.3576 - learning_rate: 2.5000e-04
# Epoch 35/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 31s 174ms/step - accuracy: 0.8519 - loss: 0.3665 - val_accuracy: 0.8768 - val_loss: 0.3547 - learning_rate: 2.5000e-04
# Epoch 36/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 158ms/step - accuracy: 0.8605 - loss: 0.3412 - val_accuracy: 0.8885 - val_loss: 0.3443 - learning_rate: 2.5000e-04
# Epoch 37/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 153ms/step - accuracy: 0.8591 - loss: 0.3616 - val_accuracy: 0.8866 - val_loss: 0.3509 - learning_rate: 2.5000e-04
# Epoch 38/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.8598 - loss: 0.3385 - val_accuracy: 0.8922 - val_loss: 0.3307 - learning_rate: 2.5000e-04
# Epoch 39/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 30s 167ms/step - accuracy: 0.8626 - loss: 0.3269 - val_accuracy: 0.8915 - val_loss: 0.3223 - learning_rate: 2.5000e-04
# Epoch 40/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 159ms/step - accuracy: 0.8669 - loss: 0.3215 - val_accuracy: 0.9032 - val_loss: 0.2994 - learning_rate: 2.5000e-04
# Epoch 41/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 154ms/step - accuracy: 0.8686 - loss: 0.3198 - val_accuracy: 0.8934 - val_loss: 0.3094 - learning_rate: 2.5000e-04
# Epoch 42/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 148ms/step - accuracy: 0.8671 - loss: 0.3403 - val_accuracy: 0.8940 - val_loss: 0.3125 - learning_rate: 2.5000e-04
# Epoch 43/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8671 - loss: 0.3430
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 153ms/step - accuracy: 0.8619 - loss: 0.3355 - val_accuracy: 0.9026 - val_loss: 0.3009 - learning_rate: 2.5000e-04
# Epoch 44/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 24s 138ms/step - accuracy: 0.8709 - loss: 0.3090 - val_accuracy: 0.9075 - val_loss: 0.2809 - learning_rate: 1.2500e-04
# Epoch 45/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 23s 132ms/step - accuracy: 0.8755 - loss: 0.3030 - val_accuracy: 0.9075 - val_loss: 0.2816 - learning_rate: 1.2500e-04
# Epoch 46/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 23s 129ms/step - accuracy: 0.8768 - loss: 0.2961 - val_accuracy: 0.9026 - val_loss: 0.2865 - learning_rate: 1.2500e-04
# Epoch 47/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 25s 139ms/step - accuracy: 0.8814 - loss: 0.2914 - val_accuracy: 0.9118 - val_loss: 0.2627 - learning_rate: 1.2500e-04
# Epoch 48/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 156ms/step - accuracy: 0.8833 - loss: 0.2897 - val_accuracy: 0.9062 - val_loss: 0.2772 - learning_rate: 1.2500e-04
# Epoch 49/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 25s 143ms/step - accuracy: 0.8842 - loss: 0.2815 - val_accuracy: 0.9050 - val_loss: 0.2678 - learning_rate: 1.2500e-04
# Epoch 50/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 24s 139ms/step - accuracy: 0.8904 - loss: 0.2730 - val_accuracy: 0.9136 - val_loss: 0.2562 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 50.

# %%
# Evaluate the model on validation data
high_acc_eval = high_acc_model.evaluate(val_dataset)
print(f"High Accuracy Model - Loss: {high_acc_eval[0]}, Accuracy: {high_acc_eval[1]}")
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9161 - loss: 0.2560
# High Accuracy Model - Loss: 0.25601768493652344, Accuracy: 0.9160539507865906

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
def plot_accuracy(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# Call the function to display the accuracy graph
plot_accuracy(history_high_acc)

# %%
# Get predictions on the test dataset
y_true = []  # True labels
y_pred = []  # Predicted labels

# Iterate over the test dataset and collect the true and predicted labels
for images, labels in test_dataset:
    predictions = high_acc_model.predict(images)
    predicted_labels = np.argmax(predictions, axis=1)  # Convert one-hot encoded predictions to class labels
    y_true.extend(labels.numpy())  # Convert tensor to numpy array and append
    y_pred.extend(predicted_labels)  # Append the predicted labels

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Classification report
report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:")
print(report)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#           A+       0.99      0.90      0.94       111
#           A-       0.86      0.86      0.86        87
#          AB+       0.98      0.97      0.97       124
#          AB-       0.95      0.90      0.92        80
#           B+       0.90      0.96      0.93        85
#           B-       0.87      0.97      0.92        78
#           O+       0.91      0.92      0.92       128
#           O-       0.93      0.93      0.93       107
#
#     accuracy                           0.93       800
#    macro avg       0.92      0.93      0.93       800
# weighted avg       0.93      0.93      0.93       800

# %%
high_acc_model.save('model.h5')  # The model will be saved as 'model.h5'
print("Model saved as HDF5 format.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as HDF5 format.

# %%
# pip show pillow
